# %% [markdown]
# ## Arena Sport

# %%
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen

# %%
url = "https://arenakit.net/shop"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode('utf-8')
html
# Out:
# '<!DOCTYPE html><html lang="en" dir="ltr"><head><meta charSet="UTF-8" data-next-head=""/><meta name="viewport" content="width=device-width, initial-scale=1.0" data-next-head=""/><link rel="icon" type="image/ico" href="https://bucket.zammit.shop/active-storage/6nqpvn3emdn8nx3r0ttzm1i20682" data-next-head=""/><meta property="og:image" content="https://bucket.zammit.shop/active-storage/7r4889q01rtbf5j6vytg4a71010j" data-next-head=""/><meta property="og:image:alt" content="Arena Kits" data-next-head=""/><meta property="og:site_name" content="Arena Kits" data-next-head=""/><meta property="og:locale" content="en" data-next-head=""/><meta name="twitter:title" content="Arena Kits" data-next-head=""/><meta name="twitter:description" content="Shop for your favorite products from Arena Kits" data-next-head=""/><meta name="twitter:image" content="https://bucket.zammit.shop/active-storage/7r4889q01rtbf5j6vytg4a71010j" data-next-head=""/><meta name="twitter:site" content="https://arenakit.net/shop" data-next-head=""/><meta name="google-site-verification" data-next-head=""/><link rel="canonical" href="https://arenakit.net/shop" data-next-head=""/><title data-next-head="">All products | Arena Kits</title><meta name="description" content="" data-next-head=""/><meta property="og:type" content="product.group" data-next-head=""/><meta property="og:title" content="All products" data-next-head=""/><meta property="og:description" content="" data-next-head=""/><meta property="og:url" content="https://arenakit.net/shop" data-next-head=""/><link rel="preconnect" href="https://fonts.googleapis.com" crossorigin="anonymous"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="anonymous"/><link rel="dns-prefetch" href="https://fonts.gstatic.com"/><link rel="dns-prefetch" href="https://fonts.googleapis.com"/><link rel="preload" href="/_next/static/css/5fb09c81e8877abf.css" as="style"/><link rel="preload" as="image" imageSrcSet="https://bucket.zammit.shop/active-storage/pamwyetz57hwjb8bs9ks7fn4algt 300w, https://bucket.zammit.shop/active-storage/pamwyetz57hwjb8bs9ks7fn4algt 300w, https://bucket.zammit.shop/active-storage/xt7grhazg66he38k5jg3njs4m6aq 768w, https://bucket.zammit.shop/active-storage/khodybgsatl70clbfe3l0jnb7vkn 1024w, https://bucket.zammit.shop/active-storage/axdq079tdkiuc78ns6i2w8mavbke 1500w" imageSizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" data-next-head=""/><link rel="preload" as="image" imageSrcSet="https://bucket.zammit.shop/active-storage/5tkb040ofgnd017wo3wk99kjvvu1 300w, https://bucket.zammit.shop/active-storage/5tkb040ofgnd017wo3wk99kjvvu1 300w, https://bucket.zammit.shop/active-storage/r0jl24nsj4hv2ziuo9lffcpfsy5m 768w, https://bucket.zammit.shop/active-storage/pwordiidxodrt4e391hgs6aaize5 1024w, https://bucket.zammit.shop/active-storage/1wmvm9bh9dur3zeioend4keyl5x1 1500w" imageSizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" data-next-head=""/><link rel="preload" as="image" imageSrcSet="https://bucket.zammit.shop/active-storage/fd2ovpkatapgi1vme7lto9uwfx0z 300w, https://bucket.zammit.shop/active-storage/fd2ovpkatapgi1vme7lto9uwfx0z 300w, https://bucket.zammit.shop/active-storage/50ao538zsbdtk50ublnz20zzsfpu 768w, https://bucket.zammit.shop/active-storage/6dfn99rvxuhyzvzq7p6sydwoq42z 1024w, https://bucket.zammit.shop/active-storage/ggzrp7i3twsk4fdtgr17v206a5yh 1500w" imageSizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" data-next-head=""/><link rel="preload" as="image" imageSrcSet="https://bucket.zammit.shop/active-storage/5pj0rei5udxgtrt5evyvkqavbroe 300w, https://bucket.zammit.shop/active-storage/5pj0rei5udxgtrt5evyvkqavbroe 300w, https://bucket.zammit.shop/active-storage/grstparwllikkx8pa83kmqp10mct 768w, https://bucket.zammit.shop/active-storage/hfs5a7y29qabp52atmixje672jin 1024w, https://bucket.zammit.shop/active-storage/eq257w8adr8x45e3x7a7ucfqa4lm 1500w" imageSizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" data-next-head=""/><link rel="preload" as="image" i ...

# %%
with open("scrapped_websites/arena_sport.txt", "w", encoding="utf-8") as f:
    f.write(html)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8" data-next-head=""/>
#   <meta content="width=device-width, initial-scale=1.0" data-next-head="" name="viewport"/>
#   <link data-next-head="" href="https://bucket.zammit.shop/active-storage/6nqpvn3emdn8nx3r0ttzm1i20682" rel="icon" type="image/ico"/>
#   <meta content="https://bucket.zammit.shop/active-storage/7r4889q01rtbf5j6vytg4a71010j" data-next-head="" property="og:image"/>
#   <meta content="Arena Kits" data-next-head="" property="og:image:alt"/>
#   <meta content="Arena Kits" data-next-head="" property="og:site_name"/>
#   <meta content="en" data-next-head="" property="og:locale"/>
#   <meta content="Arena Kits" data-next-head="" name="twitter:title"/>
#   <meta content="Shop for your favorite products from Arena Kits" data-next-head="" name="twitter:description"/>
#   <meta content="https://bucket.zammit.shop/active-storage/7r4889q01rtbf5j6vytg4a71010j" data-next-head="" name="twitter:image"/>
#   <meta content="https://arenakit.net/shop" data-next-head="" name="twitter:site"/>
#   <meta data-next-head="" name="google-site-verification"/>
#   <link data-next-head="" href="https://arenakit.net/shop" rel="canonical"/>
#   <title data-next-head="">
#    All products | Arena Kits
#   </title>
#   <meta content="" data-next-head="" name="description"/>
#   <meta content="product.group" data-next-head="" property="og:type"/>
#   <meta content="All products" data-next-head="" property="og:title"/>
#   <meta content="" data-next-head="" property="og:description"/>
#   <meta content="https://arenakit.net/shop" data-next-head="" property="og:url"/>
#   <link crossorigin="anonymous" href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
#   <link href="https://fonts.googleapis.com" rel="dns-prefetch"/>
#   <link as="style" href="/_next/static/css/5fb09c81e8877abf.css" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/pamwyetz57hwjb8bs9ks7fn4algt 300w, https://bucket.zammit.shop/active-storage/pamwyetz57hwjb8bs9ks7fn4algt 300w, https://bucket.zammit.shop/active-storage/xt7grhazg66he38k5jg3njs4m6aq 768w, https://bucket.zammit.shop/active-storage/khodybgsatl70clbfe3l0jnb7vkn 1024w, https://bucket.zammit.shop/active-storage/axdq079tdkiuc78ns6i2w8mavbke 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/5tkb040ofgnd017wo3wk99kjvvu1 300w, https://bucket.zammit.shop/active-storage/5tkb040ofgnd017wo3wk99kjvvu1 300w, https://bucket.zammit.shop/active-storage/r0jl24nsj4hv2ziuo9lffcpfsy5m 768w, https://bucket.zammit.shop/active-storage/pwordiidxodrt4e391hgs6aaize5 1024w, https://bucket.zammit.shop/active-storage/1wmvm9bh9dur3zeioend4keyl5x1 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/fd2ovpkatapgi1vme7lto9uwfx0z 300w, https://bucket.zammit.shop/active-storage/fd2ovpkatapgi1vme7lto9uwfx0z 300w, https://bucket.zammit.shop/active-storage/50ao538zsbdtk50ublnz20zzsfpu 768w, https://bucket.zammit.shop/active-storage/6dfn99rvxuhyzvzq7p6sydwoq42z 1024w, https://bucket.zammit.shop/active-storage/ggzrp7i3twsk4fdtgr17v206a5yh 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/5pj0rei5udxgtrt5evyvkqavbroe 300w, https://bucket.zammit.shop/active-storage/5pj0rei5udxgtrt5evyvkqavbroe 300w, https://bucket.zammit.shop/active-storage/grstparwllikkx8pa83kmqp10mct 768w, https://bucket.zammit.shop/active-storage/hfs5a7y29qabp52atmixje672jin 1024w, https://bucket.zammit.shop/active-storage/eq257w8adr8x45e3x7a7ucfqa4lm 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/zzkkp60fjmku2tipyhdi3jy9e4b5 300w, https://bucket.zammit.shop/active-storage/zzkkp60fjmku2tipyhdi3jy9e4b5 300w, https://bucket.zammit.shop/active-storage/a6hvozre7tg5lbsefzida0ikff0m 768w, https://bucket.zammit.shop/active-storage/sdji32hiam8ukfqt4gwhnttyx87o 1024w, https://bucket.zammit.shop/active-storage/k21r108pbad0j7elragjvlf9bpba 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/g8edgg5j3mrjltcd8ed9zxcocwz6 300w, https://bucket.zammit.shop/active-storage/g8edgg5j3mrjltcd8ed9zxcocwz6 300w, https://bucket.zammit.shop/active-storage/ww22uwuathoeqdu6x5t0xgyhxoum 768w, https://bucket.zammit.shop/active-storage/7i9axyw1tunteksoe2qtm0o79alt 1024w, https://bucket.zammit.shop/active-storage/fwaaht4p8cvbavhgw7ayek7417dd 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/qyv1gi8sy53sy39zwjhuduskwnc0 300w, https://bucket.zammit.shop/active-storage/qyv1gi8sy53sy39zwjhuduskwnc0 300w, https://bucket.zammit.shop/active-storage/f0ethtxz6ocmh6mqtuk34nwyhd7x 768w, https://bucket.zammit.shop/active-storage/di9une6ar550w9rx02g4ejuflbrj 1024w, https://bucket.zammit.shop/active-storage/jb8jq75omtid08x9jpl3yoyk5i5n 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/vlw32nge4pt3kvtrl2sj81tkvj8a 300w, https://bucket.zammit.shop/active-storage/vlw32nge4pt3kvtrl2sj81tkvj8a 300w, https://bucket.zammit.shop/active-storage/1hgd0en55r0ma7mqq9o8hys0n8at 768w, https://bucket.zammit.shop/active-storage/l0l2shw0c335j8wd62o5rv5i07y9 1024w, https://bucket.zammit.shop/active-storage/762x9bizgxo7cm03b0y7f6o1edet 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/58zydixf0pb4i5hu5t0iv74ajfk0 300w, https://bucket.zammit.shop/active-storage/58zydixf0pb4i5hu5t0iv74ajfk0 300w, https://bucket.zammit.shop/active-storage/s6zv4mc2i2flwfc231nn8221lpit 768w, https://bucket.zammit.shop/active-storage/x8dkolj7xbotxtafabo26srbfg45 1024w, https://bucket.zammit.shop/active-storage/a02bdgwxaq7x4b2flt6kacn68my9 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/09wguxsfq74ei098tz6gihtg9vzu 300w, https://bucket.zammit.shop/active-storage/09wguxsfq74ei098tz6gihtg9vzu 300w, https://bucket.zammit.shop/active-storage/08maiwwc300z6cn1ry8uwavs5k6a 768w, https://bucket.zammit.shop/active-storage/6gepp9jqf8l2u3yfbttqp0gztybr 1024w, https://bucket.zammit.shop/active-storage/z8o3z7rqdu8rh33bornxavqrdcfu 1500w" rel="preload"/>
#   <link as="image" data-next-head="" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/a83zufnaeobv20qq21dbzy3igg50 300w, https://bucket.zammit.shop/active-storage/a83zufnaeobv20qq21dbzy3igg50 300w, https://bucket.zammit.shop/active-storage/i0yz3ilt7aoyxrc0swubk0vmfoem 768w, https://bucket.zammit.shop/active-storage/155msvgyt4hi18m3tn7p76xs5fou 1024w, https://bucket.zammit.shop/active-storage/lp431gf4ssmldqgbl07du1ldtva3 1500w" rel="preload"/>
#   <style>
#   </style>
#   <link as="style" href="https://fonts.googleapis.com/css2?family=Baloo+Chettan+2&amp;family=Cairo&amp;display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#   <style>
#   </style>
#   <link data-n-g="" href="/_next/static/css/5fb09c81e8877abf.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/_next/static/chunks/polyfills-42372ed130431b0a.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/webpack-ee8adfad68d35107.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/framework-dfa58d5906dfdec0.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/main-adc6f7e7a4bc450a.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/_app-fa4d36a815931ed8.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/480-0794137f33eeeba5.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/58-cd634ba52f67f562.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/608-33e04cb4ac622adc.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/384-9702d10b9d7c90d1.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/shop/%5B%5B...collection%5D%5D-7121fa7cae3e778d.js">
#   </script>
#   <script defer="" src="/_next/static/FXYTzi5FfFV5YquO5tE0W/_buildManifest.js">
#   </script>
#   <script defer="" src="/_next/static/FXYTzi5FfFV5YquO5tE0W/_ssgManifest.js">
#   </script>
#   <style data-emotion="mantine-ltr-global animation-151xhna">
#    @-webkit-keyframes animation-151xhna{from,to{opacity:0.4;}50%{opacity:1;}}@keyframes animation-151xhna{from,to{opacity:0.4;}50%{opacity:1;}}
#   </style>
#   <style data-emotion="mantine-ltr-global animation-1n86wj5">
#    @-webkit-keyframes animation-1n86wj5{0%{-webkit-transform:translateX(-100%);-moz-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);opacity:0;}100%{-webkit-transform:translateX(0);-moz-transform:translateX(0);-ms-transform:translateX(0);transform:translateX(0);opacity:1;}}@keyframes animation-1n86wj5{0%{-webkit-transform:translateX(-100%);-moz-transform:translateX(-100%);-ms-transform:translateX(-100%);transform:translateX(-100%);opacity:0;}100%{-webkit-transform:translateX(0);-moz-transform:translateX(0);-ms-transform:translateX(0);transform:translateX(0);opacity:1;}}
#   </style>
#   <style data-emotion="mantine-ltr 1avyp1d hr6aor mycgtd 10h9l4c r4i8g0 m9wy0g 97awv4 qceo2b 111qdqv d8k4uu 4eddtv 1ujbd2v 1wpc1xj 1ryt1ht wq2p00 1emc9ft 467wo8 18d2bko 19htmtn 1dpo09d 16yt9zv 1f0vdzh n8y7xk 1275seb z1bhvy 132uuf 17h4nqu dg2pjb 1t45alw 2jxpqh 1dqf0ny xisqns idpveu bw5ax2 11yk41l 1t4ildr 1tzfn6s 1k7gco3 st0xb8 esziln 1v2h042 mqll2x 3ulk0e 1edgdrn 1d988h6 1ajh50z 3546c0 1deqy7c 16uitr9 1803iis df9yqj 1cpis47 q9qwbl 1vf457v v400m4 htyghh 1bqc44e 9m9ip8 47rr68 1n3on4n y0jkbz 1hb04cm u1v60g km5npm 1n89x3n 1fls0ik 1yfztfe zjcjnc ca5hw3 gf8orr 1m2o5mb 1pmp9d4 1uekwlh bdn569 1ffhapy ycmjhx 1ocyygj 5mded1 cimwj 88ralc">
#    .mantine-ltr-hr6aor{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;}.mantine-ltr-mycgtd{-webkit-flex:1;-ms-flex:1;flex:1;width:100vw;box-sizing:border-box;min-height:100vh;padding-top:calc(var(--mantine-header-height, 0px) + 0rem);padding-bottom:calc(var(--mantine-footer-height, 0px) + 0rem);padding-left:calc(var(--mantine-navbar-width, 0px) + 0rem);padding-right:calc(var(--mantine-aside-width, 0px) + 0rem);min-height:-webkit-fit-content;min-height:-moz-fit-content;min-height:fit-content;}@media (max-width: -0.0625em){.mantine-ltr-mycgtd{padding-left:0rem;padding-right:0rem;}}.mantine-ltr-10h9l4c{margin:calc(-0rem / 2);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:start;-ms-flex-pack:start;-webkit-justify-content:flex-start;justify-content:flex-start;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;padding:0.9375rem;}.mantine-ltr-r4i8g0{box-sizing:border-box;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;padding:calc(0rem / 2);-webkit-flex-basis:16.666666666666668%;-ms-flex-preferred-size:16.666666666666668%;flex-basis:16.666666666666668%;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;max-width:16.666666666666668%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-ms-flex-pack:start;-webkit-justify-content:flex-start;justify-content:flex-start;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}@media (min-width: 36em){.mantine-ltr-r4i8g0{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}@media (min-width: 48em){.mantine-ltr-r4i8g0{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}@media (min-width: 62em){.mantine-ltr-r4i8g0{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}@media (min-width: 75em){.mantine-ltr-r4i8g0{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}@media (min-width: 88em){.mantine-ltr-r4i8g0{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}.mantine-ltr-m9wy0g{max-width:50%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;height:3.125rem;}.mantine-ltr-97awv4{box-sizing:border-box;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;padding:calc(0rem / 2);-webkit-flex-basis:58.333333333333336%;-ms-flex-preferred-size:58.333333333333336%;flex-basis:58.333333333333336%;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;max-width:58.333333333333336%;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}@media (min-width: 36em){.mantine-ltr-97awv4{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}@media (min-width: 48em){.mantine-ltr-97awv4{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}@media (min-width: 62em){.mantine-ltr-97awv4{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}@media (min-width: 75em){.mantine-ltr-97awv4{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}@media (min-width: 88em){.mantine-ltr-97awv4{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}}.mantine-ltr-qceo2b{box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;gap:0.625rem;-webkit-flex:1;-ms-flex:1;flex:1;}.mantine-ltr-qceo2b>*{box-sizing:border-box;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}.mantine-ltr-111qdqv{box-sizing:border-box;-webkit- ...
#   </style>
#   <style data-emotion="mantine-rtl-global animation-1n86wj5">
#    @keyframes animation-1n86wj5{0%{transform:translateX(100%);opacity:0;}100%{transform:translateX(0);opacity:1;}}
#   </style>
#   <style data-emotion="mantine-rtl-global animation-151xhna">
#    @keyframes animation-151xhna{from,to{opacity:0.4;}50%{opacity:1;}}
#   </style>
#   <style data-emotion="mantine-rtl ">
#   </style>
#  </head>
#  <body>
#   <link as="image" href="https://bucket.zammit.shop/active-storage/d6017dea93h8iuge373h5jxsv142" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/pamwyetz57hwjb8bs9ks7fn4algt 300w, https://bucket.zammit.shop/active-storage/pamwyetz57hwjb8bs9ks7fn4algt 300w, https://bucket.zammit.shop/active-storage/xt7grhazg66he38k5jg3njs4m6aq 768w, https://bucket.zammit.shop/active-storage/khodybgsatl70clbfe3l0jnb7vkn 1024w, https://bucket.zammit.shop/active-storage/axdq079tdkiuc78ns6i2w8mavbke 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/5tkb040ofgnd017wo3wk99kjvvu1 300w, https://bucket.zammit.shop/active-storage/5tkb040ofgnd017wo3wk99kjvvu1 300w, https://bucket.zammit.shop/active-storage/r0jl24nsj4hv2ziuo9lffcpfsy5m 768w, https://bucket.zammit.shop/active-storage/pwordiidxodrt4e391hgs6aaize5 1024w, https://bucket.zammit.shop/active-storage/1wmvm9bh9dur3zeioend4keyl5x1 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/fd2ovpkatapgi1vme7lto9uwfx0z 300w, https://bucket.zammit.shop/active-storage/fd2ovpkatapgi1vme7lto9uwfx0z 300w, https://bucket.zammit.shop/active-storage/50ao538zsbdtk50ublnz20zzsfpu 768w, https://bucket.zammit.shop/active-storage/6dfn99rvxuhyzvzq7p6sydwoq42z 1024w, https://bucket.zammit.shop/active-storage/ggzrp7i3twsk4fdtgr17v206a5yh 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/5pj0rei5udxgtrt5evyvkqavbroe 300w, https://bucket.zammit.shop/active-storage/5pj0rei5udxgtrt5evyvkqavbroe 300w, https://bucket.zammit.shop/active-storage/grstparwllikkx8pa83kmqp10mct 768w, https://bucket.zammit.shop/active-storage/hfs5a7y29qabp52atmixje672jin 1024w, https://bucket.zammit.shop/active-storage/eq257w8adr8x45e3x7a7ucfqa4lm 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/zzkkp60fjmku2tipyhdi3jy9e4b5 300w, https://bucket.zammit.shop/active-storage/zzkkp60fjmku2tipyhdi3jy9e4b5 300w, https://bucket.zammit.shop/active-storage/a6hvozre7tg5lbsefzida0ikff0m 768w, https://bucket.zammit.shop/active-storage/sdji32hiam8ukfqt4gwhnttyx87o 1024w, https://bucket.zammit.shop/active-storage/k21r108pbad0j7elragjvlf9bpba 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/g8edgg5j3mrjltcd8ed9zxcocwz6 300w, https://bucket.zammit.shop/active-storage/g8edgg5j3mrjltcd8ed9zxcocwz6 300w, https://bucket.zammit.shop/active-storage/ww22uwuathoeqdu6x5t0xgyhxoum 768w, https://bucket.zammit.shop/active-storage/7i9axyw1tunteksoe2qtm0o79alt 1024w, https://bucket.zammit.shop/active-storage/fwaaht4p8cvbavhgw7ayek7417dd 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/qyv1gi8sy53sy39zwjhuduskwnc0 300w, https://bucket.zammit.shop/active-storage/qyv1gi8sy53sy39zwjhuduskwnc0 300w, https://bucket.zammit.shop/active-storage/f0ethtxz6ocmh6mqtuk34nwyhd7x 768w, https://bucket.zammit.shop/active-storage/di9une6ar550w9rx02g4ejuflbrj 1024w, https://bucket.zammit.shop/active-storage/jb8jq75omtid08x9jpl3yoyk5i5n 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/vlw32nge4pt3kvtrl2sj81tkvj8a 300w, https://bucket.zammit.shop/active-storage/vlw32nge4pt3kvtrl2sj81tkvj8a 300w, https://bucket.zammit.shop/active-storage/1hgd0en55r0ma7mqq9o8hys0n8at 768w, https://bucket.zammit.shop/active-storage/l0l2shw0c335j8wd62o5rv5i07y9 1024w, https://bucket.zammit.shop/active-storage/762x9bizgxo7cm03b0y7f6o1edet 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/58zydixf0pb4i5hu5t0iv74ajfk0 300w, https://bucket.zammit.shop/active-storage/58zydixf0pb4i5hu5t0iv74ajfk0 300w, https://bucket.zammit.shop/active-storage/s6zv4mc2i2flwfc231nn8221lpit 768w, https://bucket.zammit.shop/active-storage/x8dkolj7xbotxtafabo26srbfg45 1024w, https://bucket.zammit.shop/active-storage/a02bdgwxaq7x4b2flt6kacn68my9 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/09wguxsfq74ei098tz6gihtg9vzu 300w, https://bucket.zammit.shop/active-storage/09wguxsfq74ei098tz6gihtg9vzu 300w, https://bucket.zammit.shop/active-storage/08maiwwc300z6cn1ry8uwavs5k6a 768w, https://bucket.zammit.shop/active-storage/6gepp9jqf8l2u3yfbttqp0gztybr 1024w, https://bucket.zammit.shop/active-storage/z8o3z7rqdu8rh33bornxavqrdcfu 1500w" rel="preload"/>
#   <link as="image" imagesizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" imagesrcset="https://bucket.zammit.shop/active-storage/a83zufnaeobv20qq21dbzy3igg50 300w, https://bucket.zammit.shop/active-storage/a83zufnaeobv20qq21dbzy3igg50 300w, https://bucket.zammit.shop/active-storage/i0yz3ilt7aoyxrc0swubk0vmfoem 768w, https://bucket.zammit.shop/active-storage/155msvgyt4hi18m3tn7p76xs5fou 1024w, https://bucket.zammit.shop/active-storage/lp431gf4ssmldqgbl07du1ldtva3 1500w" rel="preload"/>
#   <div id="__next">
#    <div dir="ltr">
#     <div class="mantine-1ahwm91">
#      <style data-emotion="css-global 1w883ez">
#       html{font-family:sans-serif;line-height:1.15;-webkit-text-size-adjust:100%;-moz-text-size-adjust:100%;-ms-text-size-adjust:100%;text-size-adjust:100%;}body{margin:0;}article,aside,footer,header,nav,section,figcaption,figure,main{display:block;}h1{font-size:2em;}hr{box-sizing:content-box;height:0;overflow:visible;}pre{font-family:monospace,monospace;font-size:1em;}a{background:transparent;text-decoration-skip:objects;}a:active,a:hover{outline-width:0;}abbr[title]{border-bottom:none;-webkit-text-decoration:underline;text-decoration:underline;}b,strong{font-weight:bolder;}code,kbp,samp{font-family:monospace,monospace;font-size:1em;}dfn{font-style:italic;}mark{background-color:#ff0;color:#000;}small{font-size:80%;}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline;}sup{top:-0.5em;}sub{bottom:-0.25em;}audio,video{display:inline-block;}audio:not([controls]){display:none;height:0;}img{border-style:none;vertical-align:middle;}svg:not(:root){overflow:hidden;}button,input,optgroup,select,textarea{font-family:sans-serif;font-size:100%;line-height:1.15;margin:0;}button,input{overflow:visible;}button,select{text-transform:none;}button,[type=reset],[type=submit]{-webkit-appearance:button;}button::-moz-focus-inner,[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner{border-style:none;padding:0;}button:-moz-focusring,[type=button]:-moz-focusring,[type=reset]:-moz-focusring,[type=submit]:-moz-focusring{outline:0.0625rem dotted ButtonText;}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal;}progress{display:inline-block;vertical-align:baseline;}textarea{overflow:auto;}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0;}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto;}[type=search]{-webkit-appearance:none;-moz-appearance:none;-ms-appearance:none;appearance:none;}[type=search]::-webkit-search-cancel-button,[type=search]::-webkit-search-decoration{-webkit-appearance:none;-moz-appearance:none;-ms-appearance:none;appearance:none;}::-webkit-file-upload-button{-webkit-appearance:button;-moz-appearance:button;-ms-appearance:button;appearance:button;font:inherit;}details,menu{display:block;}summary{display:-webkit-box;display:-webkit-list-item;display:-ms-list-itembox;display:list-item;}canvas{display:inline-block;}template{display:none;}
#      </style>
#      <style data-emotion="css-global 2d999g">
#       *,*::before,*::after{box-sizing:border-box;}html{-webkit-print-color-scheme:light;color-scheme:light;}body{font-family:"Baloo Chettan 2"!important;background-color:#fff;color:#000;line-height:1.55;font-size:1rem;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;}
#      </style>
#      <div class="mantine-ltr-1avyp1d">
#       <div class="mantine-ltr-AppShell-root mantine-ltr-bw5ax2">
#        <header class="mantine-ltr-Header-root mantine-ltr-11yk41l" style="transition:background-color 0.3s ease, border-color 0.3s ease;border-bottom-color:transparent;background-color:#ffffff">
#         <div class="mantine-ltr-Grid-root mantine-ltr-10h9l4c">
#          <div class="mantine-ltr-Grid-col mantine-ltr-r4i8g0">
#           <a class="mantine-ltr-m9wy0g" href="/en">
#            <img alt="Arena Kits" height="50" src="https://bucket.zammit.shop/active-storage/d6017dea93h8iuge373h5jxsv142" style="object-fit:contain"/>
#           </a>
#          </div>
#          <div class="mantine-ltr-Grid-col mantine-ltr-97awv4">
#           <div class="mantine-ltr-Group-root mantine-ltr-qceo2b">
#            <div class="mantine-ltr-Text-root mantine-ltr-y0jkbz" style="text-decoration:none;cursor:pointer">
#             Home
#            </div>
#            <div class="mantine-ltr-Text-root mantine-ltr-y0jkbz" style="text-decoration:none;cursor:pointer">
#             All products
#            </div>
#            <div class="mantine-ltr-Text-root mantine-ltr-y0jkbz" style="text-decoration:none;cursor:pointer">
#             Discounted Items
#            </div>
#            <div class="mantine-ltr-Text-root mantine-ltr-y0jkbz" style="text-decoration:none;cursor:pointer">
#             Shipping policy
#            </div>
#           </div>
#          </div>
#          <div class="mantine-ltr-Grid-col mantine-ltr-111qdqv" style="color:#2f5831ff;justify-content:flex-end;align-items:center">
#           <div class="mantine-ltr-Group-root mantine-ltr-d8k4uu" id="aside-children" style="flex-direction:row;align-items:center">
#            <button aria-controls="mantine-«Rlsmj96»-dropdown" aria-expanded="false" aria-haspopup="menu" class="mantine-ltr-UnstyledButton-root mantine-ltr-ActionIcon-root mantine-ltr-1hb04cm" id="mantine-«Rlsmj96»-target" title="account" type="button">
#             <svg class="tabler-icon tabler-icon-user" fill="none" height="24" stroke="#2f5831ff" stroke-linecap="round" stroke-linejoin="round" stroke-width="1" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M8 7a4 4 0 1 0 8 0a4 4 0 0 0 -8 0">
#              </path>
#              <path d="M6 21v-2a4 4 0 0 1 4 -4h4a4 4 0 0 1 4 4v2">
#              </path>
#             </svg>
#            </button>
#           </div>
#           <div class="mantine-ltr-Group-root mantine-ltr-d8k4uu" id="header-children">
#            <button class="mantine-ltr-UnstyledButton-root mantine-ltr-ActionIcon-root mantine-ltr-1hb04cm" title="search" type="button">
#             <svg class="tabler-icon tabler-icon-search" fill="none" height="24" stroke="#2f5831ff" stroke-linecap="round" stroke-linejoin="round" stroke-width="1" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M10 10m-7 0a7 7 0 1 0 14 0a7 7 0 1 0 -14 0">
#              </path>
#              <path d="M21 21l-6 -6">
#              </path>
#             </svg>
#            </button>
#            <button class="mantine-ltr-UnstyledButton-root mantine-ltr-ActionIcon-root mantine-ltr-1hb04cm" title="wishlist" type="button">
#             <svg class="tabler-icon tabler-icon-heart" fill="none" height="24" stroke="#2f5831ff" stroke-linecap="round" stroke-linejoin="round" stroke-width="1" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M19.5 12.572l-7.5 7.428l-7.5 -7.428a5 5 0 1 1 7.5 -6.566a5 5 0 1 1 7.5 6.572">
#              </path>
#             </svg>
#            </button>
#            <button class="mantine-ltr-UnstyledButton-root mantine-ltr-ActionIcon-root mantine-ltr-1hb04cm" title="cart" type="button">
#             <svg class="tabler-icon tabler-icon-shopping-bag" fill="none" height="24" stroke="#2f5831ff" stroke-linecap="round" stroke-linejoin="round" stroke-width="1" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M6.331 8h11.339a2 2 0 0 1 1.977 2.304l-1.255 8.152a3 3 0 0 1 -2.966 2.544h-6.852a3 3 0 0 1 -2.965 -2.544l-1.255 -8.152a2 2 0 0 1 1.977 -2.304z">
#              </path>
#              <path d="M9 11v-5a3 3 0 0 1 6 0v5">
#              </path>
#             </svg>
#            </button>
#           </div>
#          </div>
#         </div>
#         <style data-emotion="css-global d7rje8">
#          :root{--mantine-header-height:auto;}
#         </style>
#        </header>
#        <div class="mantine-ltr-hr6aor mantine-ltr-AppShell-body">
#         <main class="mantine-ltr-mycgtd mantine-ltr-AppShell-main">
#          <div class="mantine-ltr-1avyp1d">
#           <div class="mantine-ltr-u1v60g" company="[object Object]" order="2" theme="[object Object]">
#           </div>
#          </div>
#          <div class="mantine-ltr-4eddtv">
#           <div class="mantine-ltr-Breadcrumbs-root mantine-ltr-1ujbd2v">
#            <a class="mantine-ltr-Text-root mantine-ltr-Anchor-root mantine-ltr-1t4ildr" href="/en">
#             Home
#            </a>
#            <div class="mantine-ltr-Text-root mantine-ltr-Breadcrumbs-separator mantine-ltr-1tzfn6s">
#             <svg class="tabler-icon tabler-icon-chevron-right" fill="none" height="16" stroke="#000000ff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" style="transform:none" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
#              <path d="M9 6l6 6l-6 6">
#              </path>
#             </svg>
#            </div>
#            <div class="mantine-ltr-Text-root mantine-ltr-Breadcrumbs-breadcrumb mantine-ltr-1k7gco3">
#             All products
#            </div>
#           </div>
#           <div class="mantine-ltr-Divider-root mantine-ltr-Divider-horizontal mantine-ltr-mqll2x" role="separator">
#           </div>
#           <div class="mantine-ltr-wq2p00">
#            <div class="mantine-ltr-Text-root mantine-ltr-st0xb8">
#             All products
#            </div>
#           </div>
#           <div class="mantine-ltr-1avyp1d">
#            <div class="mantine-ltr-1avyp1d">
#             <div class="mantine-ltr-Group-root mantine-ltr-1emc9ft">
#              <div class="mantine-ltr-Group-root mantine-ltr-1edgdrn">
#               <div>
#                <button class="mantine-ltr-UnstyledButton-root mantine-ltr-Button-root mantine-ltr-esziln" data-button="true" type="button">
#                 <div class="mantine-ltr-1wpc1xj mantine-ltr-Button-inner">
#                  <span class="mantine-ltr-1ryt1ht mantine-ltr-Button-label">
#                   Sort
#                  </span>
#                  <span class="mantine-ltr-Button-icon mantine-ltr-Button-rightIcon mantine-ltr-467wo8">
#                   <svg class="tabler-icon tabler-icon-chevron-down" fill="none" height="16" stroke="#000000ff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
#                    <path d="M6 9l6 6l6 -6">
#                    </path>
#                   </svg>
#                  </span>
#                 </div>
#                </button>
#                <div class="mantine-ltr-Container-root mantine-ltr-km5npm">
#                 <div class="mantine-ltr-1d988h6">
#                  <div class="mantine-ltr-1ajh50z">
#                   <div class="mantine-ltr-ScrollArea-root mantine-ltr-1deqy7c" dir="ltr" style="position:relative;--radix-scroll-area-corner-width:0px;--radix-scroll-area-corner-height:0px">
#                    <style>
#                     [data-radix-scroll-area-viewport]{scrollbar-width:none;-ms-overflow-style:none;-webkit-overflow-scrolling:touch;}[data-radix-scroll-area-viewport]::-webkit-scrollbar{display:none}
#                    </style>
#                    <div class="mantine-ltr-3546c0 mantine-ltr-ScrollArea-viewport" data-radix-scroll-area-viewport="" style="overflow-x:hidden;overflow-y:hidden">
#                     <div style="min-width:100%;display:table">
#                      <div class="mantine-ltr-InputWrapper-root mantine-ltr-RadioGroup-root mantine-ltr-1n89x3n">
#                       <div class="mantine-ltr-Radio-root mantine-ltr-1yfztfe">
#                        <div class="mantine-ltr-Radio-body mantine-ltr-df9yqj">
#                         <div class="mantine-ltr-16uitr9 mantine-ltr-Radio-inner">
#                          <input class="mantine-ltr-1fls0ik mantine-ltr-Radio-radio" id="mantine-«R1f32iflaj96»" name="mantine-«R132iflaj96»" type="radio" value="created_at_desc"/>
#                          <svg aria-hidden="true" class="___ref-icon mantine-ltr-1803iis mantine-ltr-Radio-icon" fill="none" viewbox="0 0 5 5" xmlns="http://www.w3.org/2000/svg">
#                           <path d="M0 2.5a2.5 2.5 0 115 0 2.5 2.5 0 01-5 0z" fill="currentColor">
#                           </path>
#                          </svg>
#                         </div>
#                         <div class="mantine-ltr-1v2h042 mantine-ltr-Radio-labelWrapper">
#                          <label class="mantine-ltr-Radio-label mantine-ltr-1cpis47" for="mantine-«R1f32iflaj96»">
#                           Most recent
#                          </label>
#                         </div>
#                        </div>
#                       </div>
#                       <div class="mantine-ltr-Radio-root mantine-ltr-1yfztfe">
#                        <div class="mantine-ltr-Radio-body mantine-ltr-df9yqj">
#                         <div class="mantine-ltr-16uitr9 mantine-ltr-Radio-inner">
#                          <input class="mantine-ltr-1fls0ik mantine-ltr-Radio-radio" id="mantine-«R2f32iflaj96»" name="mantine-«R132iflaj96»" type="radio" value="name_asc"/>
#                          <svg aria-hidden="true" class="___ref-icon mantine-ltr-1803iis mantine-ltr-Radio-icon" fill="none" viewbox="0 0 5 5" xmlns="http://www.w3.org/2000/svg">
#                           <path d="M0 2.5a2.5 2.5 0 115 0 2.5 2.5 0 01-5 0z" fill="currentColor">
#                           </path>
#                          </svg>
#                         </div>
#                         <div class="mantine-ltr-1v2h042 mantine-ltr-Radio-labelWrapper">
#                          <label class="mantine-ltr-Radio-label mantine-ltr-1cpis47" for="mantine-«R2f32iflaj96»">
#                           Name: A to Z
#                          </label>
#                         </div>
#                        </div>
#                       </div>
#                       <div class="mantine-ltr-Radio-root mantine-ltr-1yfztfe">
#                        <div class="mantine-ltr-Radio-body mantine-ltr-df9yqj">
#                         <div class="mantine-ltr-16uitr9 mantine-ltr-Radio-inner">
#                          <input class="mantine-ltr-1fls0ik mantine-ltr-Radio-radio" id="mantine-«R3f32iflaj96»" name="mantine-«R132iflaj96»" type="radio" value="name_desc"/>
#                          <svg aria-hidden="true" class="___ref-icon mantine-ltr-1803iis mantine-ltr-Radio-icon" fill="none" viewbox="0 0 5 5" xmlns="http://www.w3.org/2000/svg">
#                           <path d="M0 2.5a2.5 2.5 0 115 0 2.5 2.5 0 01-5 0z" fill="currentColor">
#                           </path>
#                          </svg>
#                         </div>
#                         <div class="mantine-ltr-1v2h042 mantine-ltr-Radio-labelWrapper">
#                          <label class="mantine-ltr-Radio-label mantine-ltr-1cpis47" for="mantine-«R3f32iflaj96»">
#                           Name: Z to A
#                          </label>
#                         </div>
#                        </div>
#                       </div>
#                       <div class="mantine-ltr-Radio-root mantine-ltr-1yfztfe">
#                        <div class="mantine-ltr-Radio-body mantine-ltr-df9yqj">
#                         <div class="mantine-ltr-16uitr9 mantine-ltr-Radio-inner">
#                          <input class="mantine-ltr-1fls0ik mantine-ltr-Radio-radio" id="mantine-«R4f32iflaj96»" name="mantine-«R132iflaj96»" type="radio" value="price_asc"/>
#                          <svg aria-hidden="true" class="___ref-icon mantine-ltr-1803iis mantine-ltr-Radio-icon" fill="none" viewbox="0 0 5 5" xmlns="http://www.w3.org/2000/svg">
#                           <path d="M0 2.5a2.5 2.5 0 115 0 2.5 2.5 0 01-5 0z" fill="currentColor">
#                           </path>
#                          </svg>
#                         </div>
#                         <div class="mantine-ltr-1v2h042 mantine-ltr-Radio-labelWrapper">
#                          <label class="mantine-ltr-Radio-label mantine-ltr-1cpis47" for="mantine-«R4f32iflaj96»">
#                           Price: low to high
#                          </label>
#                         </div>
#                        </div>
#                       </div>
#                       <div class="mantine-ltr-Radio-root mantine-ltr-1yfztfe">
#                        <div class="mantine-ltr-Radio-body mantine-ltr-df9yqj">
#                         <div class="mantine-ltr-16uitr9 mantine-ltr-Radio-inner">
#                          <input class="mantine-ltr-1fls0ik mantine-ltr-Radio-radio" id="mantine-«R5f32iflaj96»" name="mantine-«R132iflaj96»" type="radio" value="price_desc"/>
#                          <svg aria-hidden="true" class="___ref-icon mantine-ltr-1803iis mantine-ltr-Radio-icon" fill="none" viewbox="0 0 5 5" xmlns="http://www.w3.org/2000/svg">
#                           <path d="M0 2.5a2.5 2.5 0 115 0 2.5 2.5 0 01-5 0z" fill="currentColor">
#                           </path>
#                          </svg>
#                         </div>
#                         <div class="mantine-ltr-1v2h042 mantine-ltr-Radio-labelWrapper">
#                          <label class="mantine-ltr-Radio-label mantine-ltr-1cpis47" for="mantine-«R5f32iflaj96»">
#                           Price: high to low
#                          </label>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div>
#                <button class="mantine-ltr-UnstyledButton-root mantine-ltr-Button-root mantine-ltr-esziln" data-button="true" type="button">
#                 <div class="mantine-ltr-1wpc1xj mantine-ltr-Button-inner">
#                  <span class="mantine-ltr-1ryt1ht mantine-ltr-Button-label">
#                   size
#                  </span>
#                  <span class="mantine-ltr-Button-icon mantine-ltr-Button-rightIcon mantine-ltr-467wo8">
#                   <svg class="tabler-icon tabler-icon-chevron-down" fill="none" height="16" stroke="#000000ff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
#                    <path d="M6 9l6 6l6 -6">
#                    </path>
#                   </svg>
#                  </span>
#                 </div>
#                </button>
#                <div class="mantine-ltr-Container-root mantine-ltr-km5npm">
#                 <div class="mantine-ltr-1d988h6">
#                  <div class="mantine-ltr-1ajh50z">
#                   <div class="mantine-ltr-ScrollArea-root mantine-ltr-1deqy7c" dir="ltr" style="position:relative;--radix-scroll-area-corner-width:0px;--radix-scroll-area-corner-height:0px">
#                    <style>
#                     [data-radix-scroll-area-viewport]{scrollbar-width:none;-ms-overflow-style:none;-webkit-overflow-scrolling:touch;}[data-radix-scroll-area-viewport]::-webkit-scrollbar{display:none}
#                    </style>
#                    <div class="mantine-ltr-3546c0 mantine-ltr-ScrollArea-viewport" data-radix-scroll-area-viewport="" style="overflow-x:hidden;overflow-y:hidden">
#                     <div style="min-width:100%;display:table">
#                      <div class="mantine-ltr-InputWrapper-root mantine-ltr-CheckboxGroup-root mantine-ltr-1n89x3n">
#                       <div class="mantine-ltr-SimpleGrid-root mantine-ltr-1n3on4n">
#                        <div class="mantine-ltr-Checkbox-root mantine-ltr-ca5hw3">
#                         <div class="mantine-ltr-Checkbox-body mantine-ltr-df9yqj">
#                          <div class="mantine-ltr-1vf457v mantine-ltr-Checkbox-inner">
#                           <input class="mantine-ltr-zjcjnc mantine-ltr-Checkbox-input" id="mantine-«Rn34iflaj96»" type="checkbox" value="l"/>
#                           <svg class="___ref-icon mantine-ltr-q9qwbl mantine-ltr-Checkbox-icon" fill="none" viewbox="0 0 10 7" xmlns="http://www.w3.org/2000/svg">
#                            <path clip-rule="evenodd" d="M4 4.586L1.707 2.293A1 1 0 1 0 .293 3.707l3 3a.997.997 0 0 0 1.414 0l5-5A1 1 0 1 0 8.293.293L4 4.586z" fill="currentColor" fill-rule="evenodd">
#                            </path>
#                           </svg>
#                          </div>
#                          <div class="mantine-ltr-1v2h042 mantine-ltr-Checkbox-labelWrapper">
#                           <label class="mantine-ltr-Checkbox-label mantine-ltr-1cpis47" for="mantine-«Rn34iflaj96»">
#                            l
#                           </label>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="mantine-ltr-Checkbox-root mantine-ltr-ca5hw3">
#                         <div class="mantine-ltr-Checkbox-body mantine-ltr-df9yqj">
#                          <div class="mantine-ltr-1vf457v mantine-ltr-Checkbox-inner">
#                           <input class="mantine-ltr-zjcjnc mantine-ltr-Checkbox-input" id="mantine-«R1734iflaj96»" type="checkbox" value="m"/>
#                           <svg class="___ref-icon mantine-ltr-q9qwbl mantine-ltr-Checkbox-icon" fill="none" viewbox="0 0 10 7" xmlns="http://www.w3.org/2000/svg">
#                            <path clip-rule="evenodd" d="M4 4.586L1.707 2.293A1 1 0 1 0 .293 3.707l3 3a.997.997 0 0 0 1.414 0l5-5A1 1 0 1 0 8.293.293L4 4.586z" fill="currentColor" fill-rule="evenodd">
#                            </path>
#                           </svg>
#                          </div>
#                          <div class="mantine-ltr-1v2h042 mantine-ltr-Checkbox-labelWrapper">
#                           <label class="mantine-ltr-Checkbox-label mantine-ltr-1cpis47" for="mantine-«R1734iflaj96»">
#                            m
#                           </label>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="mantine-ltr-Checkbox-root mantine-ltr-ca5hw3">
#                         <div class="mantine-ltr-Checkbox-body mantine-ltr-df9yqj">
#                          <div class="mantine-ltr-1vf457v mantine-ltr-Checkbox-inner">
#                           <input class="mantine-ltr-zjcjnc mantine-ltr-Checkbox-input" id="mantine-«R1n34iflaj96»" type="checkbox" value="xl"/>
#                           <svg class="___ref-icon mantine-ltr-q9qwbl mantine-ltr-Checkbox-icon" fill="none" viewbox="0 0 10 7" xmlns="http://www.w3.org/2000/svg">
#                            <path clip-rule="evenodd" d="M4 4.586L1.707 2.293A1 1 0 1 0 .293 3.707l3 3a.997.997 0 0 0 1.414 0l5-5A1 1 0 1 0 8.293.293L4 4.586z" fill="currentColor" fill-rule="evenodd">
#                            </path>
#                           </svg>
#                          </div>
#                          <div class="mantine-ltr-1v2h042 mantine-ltr-Checkbox-labelWrapper">
#                           <label class="mantine-ltr-Checkbox-label mantine-ltr-1cpis47" for="mantine-«R1n34iflaj96»">
#                            xl
#                           </label>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="mantine-ltr-Checkbox-root mantine-ltr-ca5hw3">
#                         <div class="mantine-ltr-Checkbox-body mantine-ltr-df9yqj">
#                          <div class="mantine-ltr-1vf457v mantine-ltr-Checkbox-inner">
#                           <input class="mantine-ltr-zjcjnc mantine-ltr-Checkbox-input" id="mantine-«R2734iflaj96»" type="checkbox" value="xx"/>
#                           <svg class="___ref-icon mantine-ltr-q9qwbl mantine-ltr-Checkbox-icon" fill="none" viewbox="0 0 10 7" xmlns="http://www.w3.org/2000/svg">
#                            <path clip-rule="evenodd" d="M4 4.586L1.707 2.293A1 1 0 1 0 .293 3.707l3 3a.997.997 0 0 0 1.414 0l5-5A1 1 0 1 0 8.293.293L4 4.586z" fill="currentColor" fill-rule="evenodd">
#                            </path>
#                           </svg>
#                          </div>
#                          <div class="mantine-ltr-1v2h042 mantine-ltr-Checkbox-labelWrapper">
#                           <label class="mantine-ltr-Checkbox-label mantine-ltr-1cpis47" for="mantine-«R2734iflaj96»">
#                            xx
#                           </label>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="mantine-ltr-Checkbox-root mantine-ltr-ca5hw3">
#                         <div class="mantine-ltr-Checkbox-body mantine-ltr-df9yqj">
#                          <div class="mantine-ltr-1vf457v mantine-ltr-Checkbox-inner">
#                           <input class="mantine-ltr-zjcjnc mantine-ltr-Checkbox-input" id="mantine-«R2n34iflaj96»" type="checkbox" value="xxl"/>
#                           <svg class="___ref-icon mantine-ltr-q9qwbl mantine-ltr-Checkbox-icon" fill="none" viewbox="0 0 10 7" xmlns="http://www.w3.org/2000/svg">
#                            <path clip-rule="evenodd" d="M4 4.586L1.707 2.293A1 1 0 1 0 .293 3.707l3 3a.997.997 0 0 0 1.414 0l5-5A1 1 0 1 0 8.293.293L4 4.586z" fill="currentColor" fill-rule="evenodd">
#                            </path>
#                           </svg>
#                          </div>
#                          <div class="mantine-ltr-1v2h042 mantine-ltr-Checkbox-labelWrapper">
#                           <label class="mantine-ltr-Checkbox-label mantine-ltr-1cpis47" for="mantine-«R2n34iflaj96»">
#                            xxl
#                           </label>
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div>
#                <button class="mantine-ltr-UnstyledButton-root mantine-ltr-Button-root mantine-ltr-esziln" data-button="true" type="button">
#                 <div class="mantine-ltr-1wpc1xj mantine-ltr-Button-inner">
#                  <span class="mantine-ltr-1ryt1ht mantine-ltr-Button-label">
#                   price
#                  </span>
#                  <span class="mantine-ltr-Button-icon mantine-ltr-Button-rightIcon mantine-ltr-467wo8">
#                   <svg class="tabler-icon tabler-icon-chevron-down" fill="none" height="16" stroke="#000000ff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
#                    <path d="M6 9l6 6l6 -6">
#                    </path>
#                   </svg>
#                  </span>
#                 </div>
#                </button>
#                <div class="mantine-ltr-Container-root mantine-ltr-km5npm">
#                 <div class="mantine-ltr-1d988h6">
#                  <div class="mantine-ltr-1ajh50z">
#                   <div class="mantine-ltr-ScrollArea-root mantine-ltr-1deqy7c" dir="ltr" style="position:relative;--radix-scroll-area-corner-width:0px;--radix-scroll-area-corner-height:0px">
#                    <style>
#                     [data-radix-scroll-area-viewport]{scrollbar-width:none;-ms-overflow-style:none;-webkit-overflow-scrolling:touch;}[data-radix-scroll-area-viewport]::-webkit-scrollbar{display:none}
#                    </style>
#                    <div class="mantine-ltr-3546c0 mantine-ltr-ScrollArea-viewport" data-radix-scroll-area-viewport="" style="overflow-x:hidden;overflow-y:hidden">
#                     <div style="min-width:100%;display:table">
#                      <div class="mantine-ltr-InputWrapper-root mantine-ltr-RadioGroup-root mantine-ltr-1n89x3n">
#                       <div class="mantine-ltr-Radio-root mantine-ltr-1yfztfe">
#                        <div class="mantine-ltr-Radio-body mantine-ltr-df9yqj">
#                         <div class="mantine-ltr-16uitr9 mantine-ltr-Radio-inner">
# ...
#                  </div>
#                  <div class="mantine-ltr-Stack-root mantine-ltr-z1bhvy">
#                   <div class="mantine-ltr-Badge-root mantine-ltr-1ffhapy">
#                    <span class="mantine-ltr-1t45alw mantine-ltr-Badge-inner">
#                     Sold out
#                    </span>
#                   </div>
#                  </div>
#                 </div>
#                </a>
#               </div>
#               <a class="mantine-ltr-1avyp1d" href="/en/shop/products/N">
#                <div class="mantine-ltr-Group-root mantine-ltr-132uuf">
#                 <div class="mantine-ltr-Text-root mantine-ltr-bdn569">
#                  Real Madrid - Black - 2026
#                 </div>
#                </div>
#                <div class="mantine-ltr-Group-root mantine-ltr-17h4nqu" style="justify-content:flex-start;gap:10px">
#                 <div class="mantine-ltr-Text-root mantine-ltr-1pmp9d4">
#                  EGP 450
#                 </div>
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="mantine-ltr-Grid-col mantine-ltr-9m9ip8">
#              <div class="mantine-ltr-Paper-root mantine-ltr-Card-root mantine-ltr-3ulk0e">
#               <div class="mantine-ltr-idpveu">
#                <button class="mantine-ltr-UnstyledButton-root mantine-ltr-ActionIcon-root mantine-ltr-1uekwlh" type="button">
#                 <svg class="tabler-icon tabler-icon-heart" fill="none" height="24" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" style="color:#ffffffff" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M19.5 12.572l-7.5 7.428l-7.5 -7.428a5 5 0 1 1 7.5 -6.566a5 5 0 1 1 7.5 6.572">
#                  </path>
#                 </svg>
#                </button>
#               </div>
#               <div class="mantine-ltr-n8y7xk">
#                <a class="mantine-ltr-1avyp1d" href="/en/shop/products/72f619342781">
#                 <div class="mantine-ltr-1avyp1d">
#                  <div class="mantine-ltr-1275seb">
#                   <img alt="Wadi Degla - Yellow - 26 image" class="mantine-ltr-1f0vdzh" data-nimg="1" decoding="async" height="0" loading="lazy" sizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" src="https://bucket.zammit.shop/active-storage/hpzz2a4jn2ypagenpo2osmcj2exa" srcset="https://bucket.zammit.shop/active-storage/25a3h3g5nbzy5s6la4wa3j2cvduj 300w, https://bucket.zammit.shop/active-storage/25a3h3g5nbzy5s6la4wa3j2cvduj 300w, https://bucket.zammit.shop/active-storage/1cvgqfwdy4dct0mbu92p9ccyi2je 768w, https://bucket.zammit.shop/active-storage/gq3os350lrjhoamxmvycszc3uux4 1024w, https://bucket.zammit.shop/active-storage/hpzz2a4jn2ypagenpo2osmcj2exa 1500w" style="color:transparent;width:100%;height:auto;object-fit:contain;aspect-ratio:auto;transition:opacity 0.3s ease-in-out" width="0"/>
#                   <img alt="Wadi Degla - Yellow - 26 hover image" class="mantine-ltr-xisqns" data-nimg="fill" decoding="async" loading="lazy" sizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" src="https://bucket.zammit.shop/active-storage/uu0vm4l5pax5v6yo23599natma7k" srcset="https://bucket.zammit.shop/active-storage/mzyzl64uzyp9znsc10j4g70hyx68 300w, https://bucket.zammit.shop/active-storage/mzyzl64uzyp9znsc10j4g70hyx68 300w, https://bucket.zammit.shop/active-storage/xhqmvw3rtee384q96sdgb7cyrjd9 768w, https://bucket.zammit.shop/active-storage/7k24gsye45z8y3pbrdic63nigknf 1024w, https://bucket.zammit.shop/active-storage/uu0vm4l5pax5v6yo23599natma7k 1500w" style="position:absolute;height:100%;width:100%;left:0;top:0;right:0;bottom:0;object-fit:contain;color:transparent;transition:opacity 0.3s ease-in-out"/>
#                  </div>
#                  <div class="mantine-ltr-Stack-root mantine-ltr-z1bhvy">
#                  </div>
#                 </div>
#                </a>
#               </div>
#               <a class="mantine-ltr-1avyp1d" href="/en/shop/products/72f619342781">
#                <div class="mantine-ltr-Group-root mantine-ltr-132uuf">
#                 <div class="mantine-ltr-Text-root mantine-ltr-bdn569">
#                  Wadi Degla - Yellow - 26
#                 </div>
#                </div>
#                <div class="mantine-ltr-Group-root mantine-ltr-17h4nqu" style="justify-content:flex-start;gap:10px">
#                 <div class="mantine-ltr-Text-root mantine-ltr-1pmp9d4">
#                  EGP 325
#                 </div>
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="mantine-ltr-Grid-col mantine-ltr-9m9ip8">
#              <div class="mantine-ltr-Paper-root mantine-ltr-Card-root mantine-ltr-3ulk0e">
#               <div class="mantine-ltr-idpveu">
#                <button class="mantine-ltr-UnstyledButton-root mantine-ltr-ActionIcon-root mantine-ltr-1uekwlh" type="button">
#                 <svg class="tabler-icon tabler-icon-heart" fill="none" height="24" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" style="color:#ffffffff" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M19.5 12.572l-7.5 7.428l-7.5 -7.428a5 5 0 1 1 7.5 -6.566a5 5 0 1 1 7.5 6.572">
#                  </path>
#                 </svg>
#                </button>
#               </div>
#               <div class="mantine-ltr-n8y7xk">
#                <a class="mantine-ltr-1avyp1d" href="/en/shop/products/98b9ceb674bb">
#                 <div class="mantine-ltr-1avyp1d">
#                  <div class="mantine-ltr-1275seb">
#                   <img alt="Roma - Home - 2026 image" class="mantine-ltr-1f0vdzh" data-nimg="1" decoding="async" height="0" loading="lazy" sizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" src="https://bucket.zammit.shop/active-storage/5rjw675ktcuebe2nzld09hthqwtz" srcset="https://bucket.zammit.shop/active-storage/ajmvwgb3mhcmq0myjtj99frt1pwj 300w, https://bucket.zammit.shop/active-storage/ajmvwgb3mhcmq0myjtj99frt1pwj 300w, https://bucket.zammit.shop/active-storage/n4plpiszc64or9kdlb9lcgqyob0y 768w, https://bucket.zammit.shop/active-storage/l872nw0f6kbus2emaf9bsn28jms7 1024w, https://bucket.zammit.shop/active-storage/5rjw675ktcuebe2nzld09hthqwtz 1500w" style="color:transparent;width:100%;height:auto;object-fit:contain;aspect-ratio:auto;transition:opacity 0.3s ease-in-out" width="0"/>
#                   <img alt="Roma - Home - 2026 hover image" class="mantine-ltr-xisqns" data-nimg="fill" decoding="async" loading="lazy" sizes="(max-width: 36em) 50vw, (max-width: 75em) 33vw, 25vw" src="https://bucket.zammit.shop/active-storage/re5k6bemr0b11i7o26jw9n9eksp6" srcset="https://bucket.zammit.shop/active-storage/6jwsomop49qd7gpo8nio6ht0rrnk 300w, https://bucket.zammit.shop/active-storage/6jwsomop49qd7gpo8nio6ht0rrnk 300w, https://bucket.zammit.shop/active-storage/ftszub6lqz7azloodyml24wk8t7f 768w, https://bucket.zammit.shop/active-storage/p7dcclb8307anfkmrkydmufnpi7w 1024w, https://bucket.zammit.shop/active-storage/re5k6bemr0b11i7o26jw9n9eksp6 1500w" style="position:absolute;height:100%;width:100%;left:0;top:0;right:0;bottom:0;object-fit:contain;color:transparent;transition:opacity 0.3s ease-in-out"/>
#                  </div>
#                  <div class="mantine-ltr-Stack-root mantine-ltr-z1bhvy">
#                  </div>
#                 </div>
#                </a>
#               </div>
#               <a class="mantine-ltr-1avyp1d" href="/en/shop/products/98b9ceb674bb">
#                <div class="mantine-ltr-Group-root mantine-ltr-132uuf">
#                 <div class="mantine-ltr-Text-root mantine-ltr-bdn569">
#                  Roma - Home - 2026
#                 </div>
#                </div>
#                <div class="mantine-ltr-Group-root mantine-ltr-17h4nqu" style="justify-content:flex-start;gap:10px">
#                 <div class="mantine-ltr-Text-root mantine-ltr-1pmp9d4">
#                  EGP 325
#                 </div>
#                </div>
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="mantine-ltr-1avyp1d">
#             <div class="mantine-ltr-Divider-root mantine-ltr-Divider-horizontal mantine-ltr-mqll2x" role="separator">
#             </div>
#             <div class="mantine-ltr-1avyp1d">
#              <div class="mantine-ltr-Group-root mantine-ltr-47rr68">
#               <button aria-label="Go to the previous page" class="mantine-ltr-UnstyledButton-root mantine-ltr-Pagination-control mantine-ltr-cimwj" data-disabled="true" disabled="" type="button">
#                <svg class="mantine-ltr-2jxpqh" style="width:calc(2.375rem / 2);height:calc(2.375rem / 2)" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M7.219 8l3.3 3.3-.943.943L5.333 8l4.243-4.243.943.943-3.3 3.3z" fill="currentColor">
#                 </path>
#                </svg>
#               </button>
#               <button aria-current="page" class="mantine-ltr-UnstyledButton-root mantine-ltr-Pagination-control mantine-ltr-88ralc" data-active="true" type="button">
#                1
#               </button>
#               <button class="mantine-ltr-UnstyledButton-root mantine-ltr-Pagination-control mantine-ltr-88ralc" type="button">
#                2
#               </button>
#               <button class="mantine-ltr-UnstyledButton-root mantine-ltr-Pagination-control mantine-ltr-88ralc" type="button">
#                3
#               </button>
#               <button class="mantine-ltr-UnstyledButton-root mantine-ltr-Pagination-control mantine-ltr-88ralc" type="button">
#                4
#               </button>
#               <button class="mantine-ltr-UnstyledButton-root mantine-ltr-Pagination-control mantine-ltr-88ralc" type="button">
#                5
#               </button>
#               <button class="mantine-ltr-UnstyledButton-root mantine-ltr-Pagination-control mantine-ltr-88ralc" type="button">
#                6
#               </button>
#               <button class="mantine-ltr-UnstyledButton-root mantine-ltr-Pagination-control mantine-ltr-88ralc" type="button">
#                7
#               </button>
#               <button aria-label="Go to the next page" class="mantine-ltr-UnstyledButton-root mantine-ltr-Pagination-control mantine-ltr-cimwj" type="button">
#                <svg class="mantine-ltr-2jxpqh" style="width:calc(2.375rem / 2);height:calc(2.375rem / 2)" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M8.781 8l-3.3-3.3.943-.943L10.667 8l-4.243 4.243-.943-.943 3.3-3.3z" fill="currentColor">
#                 </path>
#                </svg>
#               </button>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </main>
#        </div>
#       </div>
#      </div>
#     </div>
#     <noscript>
#      <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T7GWB73G" style="display:none;visibility:hidden" width="0">
#      </iframe>
#     </noscript>
#     <noscript>
#      <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PCVZ94QC" style="display:none;visibility:hidden" width="0">
#      </iframe>
#     </noscript>
#     <a class="mantine-Text-root mantine-Anchor-root mantine-nxa4ud" href="https://chat.whatsapp.com/Bdxo3BUpxrJ30vQXwHM7GK" rel="noopener noreferrer" target="_blank">
#      <svg class="tabler-icon tabler-icon-brand-whatsapp" fill="none" height="25" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="25" xmlns="http://www.w3.org/2000/svg">
#       <path d="M3 21l1.65 -3.8a9 9 0 1 1 3.4 2.9l-5.05 .9">
#       </path>
#       <path d="M9 10a.5 .5 0 0 0 1 0v-1a.5 .5 0 0 0 -1 0v1a5 5 0 0 0 5 5h1a.5 .5 0 0 0 0 -1h-1a.5 .5 0 0 0 0 1">
#       </path>
#      </svg>
#     </a>
#     <noscript>
#      <img height="1" src="https://www.facebook.com/tr?id=1807850899965772&amp;ev=PageView&amp;noscript=1" width="1"/>
#     </noscript>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"company":{"id":20612,"addTaxes":false,"browserIcon":"/assets/missing.png","checkoutCustomizations":[{"id":21635,"companyId":20612,"isVisible":true,"key":"country","label":null,"required":false},{"id":21631,"companyId":20612,"isVisible":true,"key":"first_name","label":"","required":false},{"id":21632,"companyId":20612,"isVisible":true,"key":"last_name","label":"","required":false},{"id":21633,"companyId":20612,"isVisible":true,"key":"phone_number","label":"Phone number (same as WhatsApp number)","required":false},{"id":21636,"companyId":20612,"isVisible":true,"key":"city","label":null,"required":false},{"id":21637,"companyId":20612,"isVisible":true,"key":"region","label":null,"required":false},{"id":21638,"companyId":20612,"isVisible":true,"key":"district","label":null,"required":false},{"id":21639,"companyId":20612,"isVisible":true,"key":"address_line1","label":null,"required":false},{"id":21640,"companyId":20612,"isVisible":true,"key":"building","label":null,"required":false},{"id":21641,"companyId":20612,"isVisible":true,"key":"floor","label":null,"required":false},{"id":21642,"companyId":20612,"isVisible":true,"key":"apartment","label":null,"required":false},{"id":21644,"companyId":20612,"isVisible":true,"key":"notes","label":null,"required":false},{"id":21645,"companyId":20612,"isVisible":true,"key":"store_pickup","label":null,"required":false},{"id":21634,"companyId":20612,"isVisible":true,"key":"email","label":"","required":false},{"id":21643,"companyId":20612,"isVisible":false,"key":"postal_code","label":"","required":false}],"checkoutMessage":null,"codFee":0,"companyLinks":[{"id":11421,"url":"https://www.facebook.com/share/19vqeMKS4R/?mibextid=wwXIfr","isEnabled":true,"name":"facebook","platformId":1},{"id":11420,"url":"https://www.instagram.com/arenasportivee?igsh=bjNzanRnM3ZhYzJw\u0026utm_source=qr","isEnabled":true,"name":"instagram","platformId":2},{"id":11422,"url":"https://chat.whatsapp.com/Bdxo3BUpxrJ30vQXwHM7GK","isEnabled":true,"name":"whatsapp","platformId":6}],"companyValues":[{"id":53782,"companyId":20612,"settingId":1,"value":"Pickup from booth","createdAt":"2025-02-13T21:10:46.197+02:00","updatedAt":"2025-02-13T21:10:46.197+02:00","key":"pick_up_text"},{"id":53783,"companyId":20612,"settingId":2,"value":false,"createdAt":"2025-02-13T21:10:46.226+02:00","updatedAt":"2025-02-13T21:10:46.226+02:00","key":"is_store_pickup_enabled"},{"id":53784,"companyId":20612,"settingId":3,"value":false,"createdAt":"2025-02-13T21:10:46.257+02:00","updatedAt":"2025-02-13T21:10:46.257+02:00","key":"is_sku_enforced"}],"country":"egypt","createdAt":"2025-02-13T21:10:43.505+02:00","customScript":null,"customUrl":"arenakit.net","defaultStoreLanguage":"en","emailHeadline":null,"facebookChatKey":"","facebookPixelKey":null,"features":["theming","pos-app","pos-analytics","shop-analytics"],"gameballApiKey":null,"geideaMerchantPublicKey":null,"googleAnalyticsKey":"G-2JHV79CVEV","googleSiteVerificationKey":null,"googleTagManagerKey":"GTM-PCVZ94QC","industryId":146,"isDemo":false,"logoUrl":null,"metaKeys":[{"id":1130,"facebookPixelKey":"1807850899965772"}],"microsoftClarityId":null,"minimumOrderTotal":0,"name":"Arena Kits","paymentCurrency":"EGP","paymobPublicKey":null,"paytabsProfileId":null,"priceDecimalPoints":0,"priceTemplate":null,"returnAndRefundPolicy":"Orders in Cairo \u0026 Giza are shipped within 2-3 business days, and orders in other governorates are shipped within 8 - 9 business days.\n\n","sMaxage":null,"seoDescription":"","seoKeywords":"","shippingPolicy":null,"showPoweredBy":true,"status":"active","storeFeatures":[{"id":51,"name":"show_whats_app_bubble"},{"id":5,"name":"show_colors_as_dropdown"},{"id":8,"name":"zoom_images"},{"id":55,"name":"hide_product_items_left"},{"id":57,"name":"abandoned_carts_automated_emails"},{"id":60,"name":"show_secondary_img_on_hover"},{"id":63,"name":"out_stock_notification"},{"id":64,"name":"back_in_stock_notification"},{"id":65,"name":"wishlist"},{"id":66,"name":"a ...
#   </script>
#  </body>
# </html>

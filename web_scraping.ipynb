# %% [markdown]
# First website

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.scrapingbee.com/'

page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta content="Hugo 0.139.0" name="generator"/>\n  <script>\n   (function(e,t,n,s,o){e[s]=e[s]||[],e[s].push({"gtm.start":(new Date).getTime(),event:"gtm.js"});var a=t.getElementsByTagName(n)[0],i=t.createElement(n),r=s!="dataLayer"?"&l="+s:"";i.async=!0,i.src="https://www.googletagmanager.com/gtm.js?id="+o+r,a.parentNode.insertBefore(i,a)})(window,document,"script","dataLayer","GTM-P4H32H5J")\n  </script>\n  <script defer="" src="https://app.termly.io/resource-blocker/5011f07d-039f-48ff-a424-925cf08bc26e?autoBlock=off" type="text/javascript">\n  </script>\n  <title>\n   ScrapingBee – The Best Web Scraping API\n  </title>\n  <meta charset="utf-8"/>\n  <meta content="ScrapingBee is the best web scraping API that handles proxies and headless browsers for you — so you can focus on extracting the data you need." name="description"/>\n  <meta content="width=device-width" initial-scale="1" maximum-scale="1" name="viewport"/>\n  <meta content="
# ...

# %%
from urllib.request import urlopen

url = "http://olympus.realpython.org/profiles/aphrodite"

# %%
page = urlopen(url)

# %%
html_bytes = page.read()

# %%
html = html_bytes.decode('utf-8')

# %%
html
# Out:
# '<html>\n<head>\n<title>Profile: Aphrodite</title>\n</head>\n<body bgcolor="yellow">\n<center>\n<br><br>\n<img src="/static/aphrodite.gif" />\n<h2>Name: Aphrodite</h2>\n<br><br>\nFavorite animal: Dove\n<br><br>\nFavorite color: Red\n<br><br>\nHometown: Mount Olympus\n</center>\n</body>\n</html>\n'

# %% [markdown]
# Scraping Football Table

# %%
url = "https://www.filgoal.com/#"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode('utf-8')
html
# Out:
# '\r\n<!doctype html>\r\n<!--[if gt IE 8]><!-->\r\n<html class="no-js" lang="ar">\r\n<!--<![endif]-->\r\n<head>\r\n    <meta charset="UTF-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n    <title>FilGoal | فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى</title>\r\n\r\n\r\n\r\n<!-- Search Engine -->\r\n<meta name="keywords" property="keywords" content="" />\r\n<meta name="description" property="description" content="في الجول - FilGoal أشهر وأسرع موقع رياضي مصري وعربي ، تغطية إخبارية متميزة لكافة الأحداث الرياضية في مصر والعالم ، انفرادات الدورى الأهلي والزمالك ، ن" />\r\n<meta name="image" property="image" content="https://www.filgoal.com/images/filgoal.png" />\r\n\r\n<!-- Schema.org for Google -->\r\n<meta itemprop="name" content="فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى" />\r\n<meta itemprop="description" content="في الجول - FilGoal أشهر وأسرع موقع رياضي مصري وعربي ، تغطية إخبارية متميزة لكافة الأحداث الرياضية في مصر والعالم ، انفراد
# ...

# %%
with open("scrapped_websites/page_string.txt", "w", encoding="utf-8") as f:
    f.write(html)

# %%
type(html)
# Out:
# str

# %%
type(html)
# Out:
# str

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="ar">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    FilGoal | فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى
#   </title>
#   <!-- Search Engine -->
#   <meta content="" name="keywords" property="keywords">
#    <meta content="في الجول - FilGoal أشهر وأسرع موقع رياضي مصري وعربي ، تغطية إخبارية متميزة لكافة الأحداث الرياضية في مصر والعالم ، انفرادات الدورى الأهلي والزمالك ، ن" name="description" property="description">
#     <meta content="https://www.filgoal.com/images/filgoal.png" name="image" property="image"/>
#     <!-- Schema.org for Google -->
#     <meta content="فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى" itemprop="name"/>
# ...

# %%
soup.title
# Out:
# <title>FilGoal | فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى</title>

# %%
soup.script
# Out:
# <script>
#     if (window.sessionStorage) {
#         sessionStorage.clear();
#     }
#
#     dataLayer = [];
#     dataLayer.push({ 'Device': 'Desktop' });
#     function setCookie(cname, cvalue, exdays, path) {
#         var d = new Date();
#         d.setTime(d.getTime() + (exdays * 24 * 60 * 60 * 1000));
#         document.cookie = cname + "=" + cvalue + "; " + "expires=" + d.toUTCString() + ";path=" + path;
#     }
#     function setCookieNoExpire(cname, cvalue, path) {
#         document.cookie = cname + "=" + cvalue + "; " + "path=" + path;
#     }
#     function getCookie(cname) {
#         var name = cname + "=";
#         var ca = document.cookie.split(';');
#         for (var i = 0; i < ca.length; i++) {
#             var c = ca[i];
#             while (c.charAt(0) == ' ') c = c.substring(1);
#             if (c.indexOf(name) == 0) return c.substring(name.length, c.length);
#         }
#         return null;
#     }
#     function deleteCookie(name) {
# ...

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# 'FilGoal | فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى'

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.p

# %%
soup.a
# Out:
# <a href="#" id="submit-search">
# <svg class="search-ico" viewbox="0 0 100 100"><use xlink:href="#search"></use></svg>
# </a>

# %%
soup.find_all('a')
# Out:
# [<a href="#" id="submit-search">
#  <svg class="search-ico" viewbox="0 0 100 100"><use xlink:href="#search"></use></svg>
#  </a>,
#  <a href="https://fantasy.filgoal.com" target="_blank"><img class="clazy" data-src="/images/menu/fantasy.png" data-src-mobile="/images/menu/fantasy_sm.jpg"/></a>,
#  <a href="https://predictandwin.filgoal.com" target="_blank"><img class="clazy" data-src="/images/menu/paw.png" data-src-mobile="/images/menu/paw_sm.jpg"/></a>,
#  <a href="/?menu=true"><svg><use xlink:href="#menu_home"></use></svg> الرئيسية</a>,
#  <a href="/articles"><svg><use xlink:href="#menu_news"></use></svg> أخبار</a>,
#  <a href="/matches"><svg><use xlink:href="#menu_matches"></use></svg> مباريات</a>,
#  <a href="https://mercato.filgoal.com/?utm_source=fg_top_menu"><svg><use xlink:href="#menu_news"></use></svg> ميركاتو</a>,
# ...

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #
# https://fantasy.filgoal.com
# https://predictandwin.filgoal.com
# /?menu=true
# /articles
# /matches
# https://mercato.filgoal.com/?utm_source=fg_top_menu
# https://fantasy.filgoal.com
# https://predictandwin.filgoal.com
# /videos
# /albums
# /authors
# /games
# /championships/1524/الدوري-المصري
# /championships/1503/الدوري-الإنجليزي-الممتاز
# /championships/1502/الدوري-الإسباني
# /championships/1499/الدوري-الإيطالي
# /championships/1501/الدوري-الفرنسي
# /championships/1505/الدوري-الألماني
# /championships/1538/الدوري-السعودي-للمحترفين
# /championships/1510/دوري-أبطال-إفريقيا
# /championships/1546/كأس-الكونفدرالية
# /championships/1509/دوري-أبطال-أوروبا
# /championships
# /section/1/الكرة-المصرية
# /section/88/الدوري-المصري
# /section/3/الكرة-الأوروبية
# /section/23/الكرة-الإفريقية
# /section/76/منتخب-مصر
# /section/123/سعودي-في-الجول
# /section/91/الدوري-الإنجليزي
# /section/100/الدوري-الإسباني
# /section/44/دوري-أبطال-أوروبا
# /section/112/القسم-الثاني
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="ar">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    FilGoal | فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى
#   </title>
#   <!-- Search Engine -->
#   <meta content="" name="keywords" property="keywords">
#    <meta content="في الجول - FilGoal أشهر وأسرع موقع رياضي مصري وعربي ، تغطية إخبارية متميزة لكافة الأحداث الرياضية في مصر والعالم ، انفرادات الدورى الأهلي والزمالك ، ن" name="description" property="description">
#     <meta content="https://www.filgoal.com/images/filgoal.png" name="image" property="image"/>
#     <!-- Schema.org for Google -->
#     <meta content="فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى" itemprop="name"/>
# ...

# %%
soup.contents
# Out:
# ['\n',
#  'html',
#  '\n',
#  '[if gt IE 8]><!',
#  '\n',
#  <html class="no-js" lang="ar">
#  <!--<![endif]-->
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#  <title>FilGoal | فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى</title>
#  <!-- Search Engine -->
#  <meta content="" name="keywords" property="keywords">
#  <meta content="في الجول - FilGoal أشهر وأسرع موقع رياضي مصري وعربي ، تغطية إخبارية متميزة لكافة الأحداث الرياضية في مصر والعالم ، انفرادات الدورى الأهلي والزمالك ، ن" name="description" property="description">
#  <meta content="https://www.filgoal.com/images/filgoal.png" name="image" property="image"/>
#  <!-- Schema.org for Google -->
#  <meta content="فى الجول | الموقع الرياضى الرائد فى مصر و الوطن العربى" itemprop="name"/>
# ...

# %%
len(soup.contents)
# Out:
# 7

# %%
type(soup.contents[5].findAllNext())
# Out:
# bs4.element.ResultSet

# %%
len(soup.contents[5].findAllNext())
# Out:
# 1650

# %%
for i in range(len(soup.contents[5].findAllNext())):
    if soup.contents[5].findAllNext()[i].getText().count("document.addEventListener(\"DOMContentLoaded\", function") != 0:
        print(i)
# Out:
# 292

# %%
required = soup.contents[5].findAllNext()[292]

# %%
required
# Out:
# <script type="text/javascript">
#
#     document.addEventListener("DOMContentLoaded", function () {
#
# ...
